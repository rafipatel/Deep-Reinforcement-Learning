# %%
import pandas as pd
import matplotlib.pyplot as plt

df_dqn = pd.read_csv("DQN.csv")

# Plot
plt.plot(df_dqn['training_iteration'], df_dqn['episode_reward_mean'], marker='o')
plt.title('Mean Episode Reward Over Time')
plt.xlabel('Training Iteration')
plt.ylabel('Mean Episode Reward')
plt.grid(True)
plt.show()

# %%
# plt.plot(df["timesteps_total"], df["info/num_agent_steps_sampled"], label="Agent Steps Sampled")
plt.plot(df_dqn["timesteps_total"], df_dqn["info/num_agent_steps_trained"], label="Agent Steps Trained")
plt.plot(df_dqn["timesteps_total"], df_dqn["info/num_env_steps_sampled"], label="Env Steps Sampled")
# plt.plot(df["timesteps_total"], df["info/num_env_steps_trained"], label="Env Steps Trained")
plt.xlabel("Total Environment Steps")
plt.ylabel("Steps")
plt.title("Exploration vs Exploitation")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_doubledqn = pd.read_csv("doubleDQN.csv")
plt.plot(df_doubledqn['training_iteration'], df_doubledqn['episode_reward_mean'], marker='o')
plt.title('Mean Episode Reward Over Time')
plt.xlabel('Training Iteration')
plt.ylabel('Mean Episode Reward')
plt.grid(True)
plt.show()

# %%
# plt.plot(df["timesteps_total"], df["info/num_agent_steps_sampled"], label="Agent Steps Sampled")
plt.plot(df_doubledqn["timesteps_total"], df_doubledqn["info/num_agent_steps_trained"], label="Agent Steps Trained")
plt.plot(df_doubledqn["timesteps_total"], df_doubledqn["info/num_env_steps_sampled"], label="Env Steps Sampled")
# plt.plot(df["timesteps_total"], df["info/num_env_steps_trained"], label="Env Steps Trained")
plt.xlabel("Total Environment Steps")
plt.ylabel("Steps")
plt.title("Exploration vs Exploitation")
plt.legend()
plt.show()
